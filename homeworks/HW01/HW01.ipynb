# %%
import numpy as np
a = np.arange(20,30,5)
a
# Out:
# array([20, 25])

# %%
np.inf + np.inf
# Out:
# inf

# %%
np.inf - np.inf
# Out:
# nan

# %%
a = 3
b = 7
c = a ** b
c, a, b
# Out:
# (2187, 3, 7)

# %%
a = np.ones((3,1))
b = 2*np.transpose(a)
print(a.shape, b.shape)
# Out:
# (3, 1) (1, 3)

# %%
a = np.array([0, 1, 8, 27, 111, 222, 344, 555, 877])

# %%
np.int64(64)
# Out:
# np.int64(64)

# %%
np.array([27, 343])
# Out:
# array([ 27, 343])
